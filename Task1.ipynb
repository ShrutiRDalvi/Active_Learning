# %% [markdown]
# Q1. Write a program to load the iris dataset. and perform the following operations:
# 1. Compute histogram of all columns and scatter plots
# 2. Finding the mean, median, mode, and standard deviations of numerical columns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats


# Specify the URL of the Iris dataset
iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Define column names for the dataset as they weren't apart of head() when displayed
column_names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]

# Load the Iris dataset from the provided URL
iris = pd.read_csv(iris_url,header=None,names=column_names)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(iris.head())
# Out:
# First few rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Compute histograms for all columns
iris.hist()
plt.suptitle('Histograms of Iris Dataset Columns')
plt.show()

# %%
# Scatter plots
sns.pairplot(iris)
plt.suptitle('Scatter Plots of Iris Dataset Columns')
plt.show()

# %%
numerical_columns = iris.select_dtypes(include=[np.number]).columns

for column in numerical_columns:
    mean_value = iris[column].mean()
    median_value = iris[column].median()
    mode_values = stats.mode(iris[column])
    std_deviation = iris[column].std()

    print(f"\nStatistics for {column}:")
    print(f"Mean: {mean_value}")
    print(f"Median: {median_value}")
    print(f"Mode: {mode_values}")
    print(f"Standard Deviation: {std_deviation}")
# Out:
# Statistics for sepal_length:
# Mean: 5.843333333333334
# Median: 5.8
# Mode: ModeResult(mode=5.0, count=10)
# Standard Deviation: 0.828066127977863
#
# Statistics for sepal_width:
# Mean: 3.0540000000000003
# Median: 3.0
# Mode: ModeResult(mode=3.0, count=26)
# Standard Deviation: 0.4335943113621737
#
# Statistics for petal_length:
# Mean: 3.758666666666666
# Median: 4.35
# Mode: ModeResult(mode=1.5, count=14)
# Standard Deviation: 1.7644204199522626
#
# Statistics for petal_width:
# Mean: 1.1986666666666668
# Median: 1.3
# Mode: ModeResult(mode=0.2, count=28)
# Standard Deviation: 0.7631607417008411
